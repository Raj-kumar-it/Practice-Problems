# %%
##For sales dataset do a Time Series visualization
#1)_here i am importing sales data set 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('sales1.csv',  index_col="DATE")
df
# Out:
#                TV  Radio  Newspaper  Sales
# DATE
# 03-01-2006  230.1   37.8       69.2   22.1
# 04-01-2006   44.5   39.3       45.1   10.4
# 05-01-2006   17.2   45.9       69.3   12.0
# 06-01-2006  151.5   41.3       58.5   16.5
# 07-01-2006  180.8   10.8       58.4   17.9
# ...           ...    ...        ...    ...
# 17-07-2006   38.2    3.7       13.8    7.6
# 18-07-2006   94.2    4.9        8.1   14.0
# 19-07-2006  177.0    9.3        6.4   14.8
# 20-07-2006  283.6   42.0       66.2   25.5
# 21-07-2006  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
#some preprocessers or built methods to handle the in data set
#Head() Functio is used to get the first n rows  
df.head()
# Out:
#                TV  Radio  Newspaper  Sales
# DATE
# 2006-03-01  230.1   37.8       69.2   22.1
# 2006-04-01   44.5   39.3       45.1   10.4
# 2006-05-01   17.2   45.9       69.3   12.0
# 2006-06-01  151.5   41.3       58.5   16.5
# 2006-07-01  180.8   10.8       58.4   17.9

# %%
#Tail() Function is used to get the last n rows
df.tail()
# Out:
#                TV  Radio  Newspaper  Sales
# DATE
# 2006-07-17   38.2    3.7       13.8    7.6
# 2006-07-18   94.2    4.9        8.1   14.0
# 2006-07-19  177.0    9.3        6.4   14.8
# 2006-07-20  283.6   42.0       66.2   25.5
# 2006-07-21  232.1    8.6        8.7   18.4

# %%
#shape() method is used to fetch the dimensions of pandas and numpy type objects in python
df.shape
# Out:
# (200, 4)

# %%
#INDEX:It is a default index type that can be used for DataFrame or Series when there is no explicit index 
#which is provided by the user.
#By using rangeindex we can improve computing speed.
df.index
# Out:
# Index(['03-01-2006', '04-01-2006', '05-01-2006', '06-01-2006', '07-01-2006',
#        '08-01-2006', '09-01-2006', '10-01-2006', '11-01-2006', '12-01-2006',
#        ...
#        '12-07-2006', '13-07-2006', '14-07-2006', '15-07-2006', '16-07-2006',
#        '17-07-2006', '18-07-2006', '19-07-2006', '20-07-2006', '21-07-2006'],
#       dtype='object', name='DATE', length=200)

# %%
# is null() a method returns a DataFrame object where all the values are replaced with a Boolean value True For NULL values
#otherwise False
df.isnull()
# Out:
#                TV  Radio  Newspaper  Sales
# DATE
# 03-01-2006  False  False      False  False
# 04-01-2006  False  False      False  False
# 05-01-2006  False  False      False  False
# 06-01-2006  False  False      False  False
# 07-01-2006  False  False      False  False
# ...           ...    ...        ...    ...
# 17-07-2006  False  False      False  False
# 18-07-2006  False  False      False  False
# 19-07-2006  False  False      False  False
# 20-07-2006  False  False      False  False
# 21-07-2006  False  False      False  False
#
# [200 rows x 4 columns]

# %%
# not null() function detects existing/non-missing values in the DataFrame
df.notnull()
# Out:
#               TV  Radio  Newspaper  Sales
# DATE
# 03-01-2006  True   True       True   True
# 04-01-2006  True   True       True   True
# 05-01-2006  True   True       True   True
# 06-01-2006  True   True       True   True
# 07-01-2006  True   True       True   True
# ...          ...    ...        ...    ...
# 17-07-2006  True   True       True   True
# 18-07-2006  True   True       True   True
# 19-07-2006  True   True       True   True
# 20-07-2006  True   True       True   True
# 21-07-2006  True   True       True   True
#
# [200 rows x 4 columns]

# %%
#Dropna()=Remove all rows wit NULL values from the DataFrame
df.dropna()
# Out:
#                TV  Radio  Newspaper  Sales
# DATE
# 03-01-2006  230.1   37.8       69.2   22.1
# 04-01-2006   44.5   39.3       45.1   10.4
# 05-01-2006   17.2   45.9       69.3   12.0
# 06-01-2006  151.5   41.3       58.5   16.5
# 07-01-2006  180.8   10.8       58.4   17.9
# ...           ...    ...        ...    ...
# 17-07-2006   38.2    3.7       13.8    7.6
# 18-07-2006   94.2    4.9        8.1   14.0
# 19-07-2006  177.0    9.3        6.4   14.8
# 20-07-2006  283.6   42.0       66.2   25.5
# 21-07-2006  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
#The fillna() method replaces the NULL values with a specified value. 
#The fillna() method returns a new DataFrame object unless the inplace parameter is set to True
df.fillna(0)
# Out:
#                TV  Radio  Newspaper  Sales
# DATE
# 03-01-2006  230.1   37.8       69.2   22.1
# 04-01-2006   44.5   39.3       45.1   10.4
# 05-01-2006   17.2   45.9       69.3   12.0
# 06-01-2006  151.5   41.3       58.5   16.5
# 07-01-2006  180.8   10.8       58.4   17.9
# ...           ...    ...        ...    ...
# 17-07-2006   38.2    3.7       13.8    7.6
# 18-07-2006   94.2    4.9        8.1   14.0
# 19-07-2006  177.0    9.3        6.4   14.8
# 20-07-2006  283.6   42.0       66.2   25.5
# 21-07-2006  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
#To Know About DataSe
df.info
# Out:
# <bound method DataFrame.info of                TV  Radio  Newspaper  Sales
# DATE
# 03-01-2006  230.1   37.8       69.2   22.1
# 04-01-2006   44.5   39.3       45.1   10.4
# 05-01-2006   17.2   45.9       69.3   12.0
# 06-01-2006  151.5   41.3       58.5   16.5
# 07-01-2006  180.8   10.8       58.4   17.9
# ...           ...    ...        ...    ...
# 17-07-2006   38.2    3.7       13.8    7.6
# 18-07-2006   94.2    4.9        8.1   14.0
# 19-07-2006  177.0    9.3        6.4   14.8
# 20-07-2006  283.6   42.0       66.2   25.5
# 21-07-2006  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]>

# %%
#to display sepcific rows using slicing
df.iloc[5:10]
# Out:
#                TV  Radio  Newspaper  Sales
# DATE
# 08-01-2006    8.7   48.9       75.0    7.2
# 09-01-2006   57.5   32.8       23.5   11.8
# 10-01-2006  120.2   19.6       11.6   13.2
# 11-01-2006    8.6    2.1        1.0    4.8
# 12-01-2006  199.8    2.6       21.2   15.6

# %%
df.iloc[4:-1]
# Out:
#                TV  Radio  Newspaper  Sales
# DATE
# 07-01-2006  180.8   10.8       58.4   17.9
# 08-01-2006    8.7   48.9       75.0    7.2
# 09-01-2006   57.5   32.8       23.5   11.8
# 10-01-2006  120.2   19.6       11.6   13.2
# 11-01-2006    8.6    2.1        1.0    4.8
# ...           ...    ...        ...    ...
# 16-07-2006  149.7   35.6        6.0   17.3
# 17-07-2006   38.2    3.7       13.8    7.6
# 18-07-2006   94.2    4.9        8.1   14.0
# 19-07-2006  177.0    9.3        6.4   14.8
# 20-07-2006  283.6   42.0       66.2   25.5
#
# [195 rows x 4 columns]

# %%
df['Newspaper'].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
df.plot(subplots=True, figsize=(10, 12))
# Out:
# array([<AxesSubplot:xlabel='DATE'>, <AxesSubplot:xlabel='DATE'>,
#        <AxesSubplot:xlabel='DATE'>, <AxesSubplot:xlabel='DATE'>],
#       dtype=object)

# %%
#Differencing:
#Differencing is used to make the difference in values of a specified interval
df.TV.diff(2).plot(figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
df.Radio.diff(2).plot(figsize=(10, 5))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
df.Sales.diff(2).plot(figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
#Shift():
#The shift function can be used to shift the data before or after the specified time interval
#We can specify the time, and it will shift the data by one day by default
#It is helpful to see previous day data and today’s data simultaneously side by side.
df['Change'] = df.Sales.div(df.Sales.shift())
df['Change'].plot(figsize=(10, 8), fontsize=16)
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
##TV with shift function
df['Change'] = df.TV.div(df.TV.shift())
df['Change'].plot(figsize=(10, 8), fontsize=16)
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
#We can also take a specific interval of time and plot to have a clearer look
#Here we are plotting the data of only 2006-09.
df['2006-09']['Change'].plot(figsize=(10, 6))
# Out:
# C:\Users\RAJU CHOTU\AppData\Local\Temp\ipykernel_14496\3971472346.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2006-09']['Change'].plot(figsize=(10, 6))
# <AxesSubplot:xlabel='DATE'>

# %%
df['2006-4']['Change'].plot(figsize=(10, 6))
# Out:
# C:\Users\RAJU CHOTU\AppData\Local\Temp\ipykernel_14496\126833721.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2006-4']['Change'].plot(figsize=(10, 6))
# <AxesSubplot:xlabel='DATE'>
