# %% [markdown]
# # Illustrate Partial Transparency and jittering

# %%
1)# Jittering is a technique for separating overlapping marks on a view.
# jitter is usefull for random noise to the observations before generating the scatterplot.

# %%
import seaborn 
import matplotlib.pyplot as plt 
seaborn.set(style = 'whitegrid')   
tip = seaborn.load_dataset("tips")   
seaborn.stripplot(x="day", y="total_bill", data=tip) 
plt.show()

# %%
import seaborn 
import matplotlib.pyplot as plt 
# use to set style of background of plot 
seaborn.set(style = 'whitegrid') 
# loading data-set 
tips = seaborn.load_dataset("tips") 
seaborn.stripplot(x=tips["total_bill"])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
# Python program to illustrate 
# Stripplot using inbuilt data-set 
# given in seaborn 
# importing the required module 
import seaborn 
import matplotlib.pyplot as plt 
# use to set style of background of plot 
seaborn.set(style = 'whitegrid') 
# loading data-set 
tips = seaborn.load_dataset("tips") 
seaborn.stripplot(x="day", y="total_bill", data=tips, jitter=0.3)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# Python program to illustrate 
# Stripplot using inbuilt data-set 
# given in seaborn 
# importing the required module 
import seaborn 
import matplotlib.pyplot as plt 
# use to set style of background of plot 
seaborn.set(style = 'whitegrid') 
# loading data-set 
tips = seaborn.load_dataset("tips") 
seaborn.stripplot(y="total_bill", x="day", data=tips, linewidth=3)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # transparency  and jitter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('sales1.csv',  index_col="DATE")
df
plt.scatter(data = df, x = 'Radio', y = 'Newspaper', alpha = 1/5)

# %%
plt.scatter(data = df, x = 'Sales', y = 'Newspaper')

# %%
import seaborn as sb
sb.regplot(data = df, x = 'Radio', y = 'Sales', fit_reg = False,
           x_jitter = 0.5, y_jitter = 0.5, scatter_kws = {'alpha' : 1/3})
# Out:
# <AxesSubplot:xlabel='Radio', ylabel='Sales'>
