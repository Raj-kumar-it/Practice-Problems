# %%
#2)Use Differnet Color scales on the Rainfall Prediction dataset
#i am importing rainfall dataset
import matplotlib.pyplot as plt
import pandas as pd
dv1=pd.read_csv('rainfall in india 1901-2015.csv')
dv1
# Out:
#                        DIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
#some preprocessers or built-in methods()
dv1.head()
# Out:
#                     DIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
#
#    Jun-Sep  Oct-Dec
# 0   1696.3    980.3
# 1   2185.9    716.7
# 2   1874.0    690.6
# ...

# %%
dv1.tail()
# Out:
#          DIVISION  YEAR   JAN   FEB   MAR   APR    MAY    JUN    JUL    AUG  \
# 4111  LAKSHADWEEP  2011   5.1   2.8   3.1  85.9  107.2  153.6  350.2  254.0
# 4112  LAKSHADWEEP  2012  19.2   0.1   1.6  76.8   21.2  327.0  231.5  381.2
# 4113  LAKSHADWEEP  2013  26.2  34.4  37.5   5.3   88.3  426.2  296.4  154.4
# 4114  LAKSHADWEEP  2014  53.2  16.1   4.4  14.9   57.4  244.1  116.1  466.1
# 4115  LAKSHADWEEP  2015   2.2   0.5   3.7  87.1  133.1  296.6  257.5  146.4
#
#         SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# 4111  255.2  117.4  184.3   14.9  1533.7      7.9    196.2   1013.0    316.6
# 4112  179.8  145.9   12.4    8.8  1405.5     19.3     99.6   1119.5    167.1
# 4113  180.0   72.8   78.1   26.7  1426.3     60.6    131.1   1057.0    177.6
# 4114  132.2  169.2   59.0   62.3  1395.0     69.3     76.7    958.5    290.5
# 4115  160.4  165.4  231.0  159.0  1642.9      2.7    223.9    860.9    555.4

# %%
dv1.shape
# Out:
# (4116, 19)

# %%
dv1.index
# Out:
# RangeIndex(start=0, stop=4116, step=1)

# %%
dv1.isnull()
# Out:
#       DIVISION   YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0        False  False  False  False  False  False  False  False  False  False
# 1        False  False  False  False  False  False  False  False  False  False
# 2        False  False  False  False  False  False  False  False  False  False
# 3        False  False  False  False  False  False  False  False  False  False
# 4        False  False  False  False  False  False  False  False  False  False
# ...        ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 4111     False  False  False  False  False  False  False  False  False  False
# 4112     False  False  False  False  False  False  False  False  False  False
# 4113     False  False  False  False  False  False  False  False  False  False
# 4114     False  False  False  False  False  False  False  False  False  False
# 4115     False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
dv1.notnull()
# Out:
#       DIVISION  YEAR   JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP  \
# 0         True  True  True  True  True  True  True  True  True  True  True
# 1         True  True  True  True  True  True  True  True  True  True  True
# 2         True  True  True  True  True  True  True  True  True  True  True
# 3         True  True  True  True  True  True  True  True  True  True  True
# 4         True  True  True  True  True  True  True  True  True  True  True
# ...        ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 4111      True  True  True  True  True  True  True  True  True  True  True
# 4112      True  True  True  True  True  True  True  True  True  True  True
# 4113      True  True  True  True  True  True  True  True  True  True  True
# 4114      True  True  True  True  True  True  True  True  True  True  True
# 4115      True  True  True  True  True  True  True  True  True  True  True
#
#        OCT   NOV   DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# ...

# %%
#to display sepcific rows using slicing
dv1.iloc[3:6]
# Out:
#                     DIVISION  YEAR   JAN   FEB  MAR    APR    MAY    JUN  \
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4  14.7  0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3   0.0  3.3   26.9  279.5  628.7
# 5  ANDAMAN & NICOBAR ISLANDS  1906  36.6   0.0  0.0    0.0  556.1  733.3
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
# 5  247.7  320.5  164.3  267.8  128.9   79.2  2534.4     36.6    556.1
#
#    Jun-Sep  Oct-Dec
# 3   1977.6    571.0
# 4   1624.9    630.8
# 5   1465.8    475.9

# %%
dv1.info
# Out:
# <bound method DataFrame.info of                        DIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
dv1.dropna()
# Out:
#                        DIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
dv1.fillna(0)
# Out:
#                        DIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
#to change columns name in data set
dv1.rename(columns={'DIVISION':'Area'},inplace=True)
dv1
# Out:
#                            Area  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
#Dfferent Color Graphs
#1)Bar Graph
plt.bar(dv1['JAN'],dv1['FEB'])
plt.title("Bar Chart")
plt.xlabel('JAN')
plt.ylabel('FEB')
plt.show()

# %%
##HISTOGRAM FOR ANNUAL(attribute)
plt.hist(dv1['ANNUAL'])
plt.title("HISTOGRAM")
plt.show()

# %%
##HISTOGRAM FOR JAN(attribute)
plt.hist(dv1['JAN'])
plt.title("HISTOGRAM")
plt.show()

# %%
##SCATTER PLOT for  and 
plt.scatter(dv1['ANNUAL'],dv1['YEAR'],c=dv1['JAN'],s=dv1['Jan-Feb'])
plt.title("SCATTER PLOT")
plt.xlabel('ANNUAL')
plt.ylabel('YEAR')
plt.colorbar()
plt.show()

# %%
plt.plot(dv1['YEAR'])
plt.plot(dv1['ANNUAL'])
plt.title("SCATTER PLOT")
plt.xlabel('ANNUAL')
plt.ylabel('YEAR')
plt.show()

# %%
##HISTOGRAM for ANNUAL
dv1.ANNUAL.hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
##HISTOGRAM for all attributes
dv1.hist(bins=10)
# Out:
# array([[<AxesSubplot:title={'center':'YEAR'}>,
#         <AxesSubplot:title={'center':'JAN'}>,
#         <AxesSubplot:title={'center':'FEB'}>,
#         <AxesSubplot:title={'center':'MAR'}>],
#        [<AxesSubplot:title={'center':'APR'}>,
#         <AxesSubplot:title={'center':'MAY'}>,
#         <AxesSubplot:title={'center':'JUN'}>,
#         <AxesSubplot:title={'center':'JUL'}>],
#        [<AxesSubplot:title={'center':'AUG'}>,
#         <AxesSubplot:title={'center':'SEP'}>,
#         <AxesSubplot:title={'center':'OCT'}>,
#         <AxesSubplot:title={'center':'NOV'}>],
#        [<AxesSubplot:title={'center':'DEC'}>,
#         <AxesSubplot:title={'center':'ANNUAL'}>,
#         <AxesSubplot:title={'center':'Jan-Feb'}>,
#         <AxesSubplot:title={'center':'Mar-May'}>],
#        [<AxesSubplot:title={'center':'Jun-Sep'}>,
#         <AxesSubplot:title={'center':'Oct-Dec'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
##DENSITY plot for ANNUAL
dv1.ANNUAL.plot.density(color='red')
plt.show()

# %%
##DENSITY plot for YEAR
dv1.YEAR.plot.density(color='green')
plt.show()

# %%
##DENSITY plot for MAR
dv1.MAR.plot.density(color='yellow')
plt.show()

# %%
##MULTIPLE DENSITY PLOT
data_wide=dv1.pivot(columns='YEAR',values='ANNUAL')
data_wide.head()
data_wide.plot.density(figsize=(7,7),linewidth=4)
plt.xlabel("temperatures")
# Out:
# Text(0.5, 0, 'temperatures')
